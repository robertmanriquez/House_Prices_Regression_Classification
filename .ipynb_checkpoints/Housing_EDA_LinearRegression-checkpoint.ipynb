# %% [markdown]
# ### Ames, Iowa Exploratory Data Analysis + Basic Linear Regression
#
# - To gain in understanding this data set, it was necessary to understand which variables matter the most to predict our target (Sale Price).  Using some domain knowledge on what typically matters in real estate pricing (square footage, number of floors, size of the lot, etx), we can choose a starting point for this EDA and construct a basic model.
# - After some initial EDA, we're going to cut out some outliers from the most important variables and see how it improves the basic linear regression model.
# - After evaluating this basic model with just a few subjectively picked features, the next notebook will employ regularization for a model using all of the features.
#
# Starting with only the train_cleaned.csv data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV
from sklearn.preprocessing import StandardScaler

# %matplotlib inline
sns.set_style('darkgrid')


train_df = pd.read_pickle('./assets/train_cleaned.pkl')

# %%
train_df.corr()['SalePrice'].abs().sort_values(ascending = False)[0:20]
# Out:
# SalePrice         1.000000
# Overall Qual      0.800207
# Exter Qual        0.712146
# Gr Liv Area       0.697038
# Kitchen Qual      0.692336
# Garage Area       0.649897
# Garage Cars       0.647781
# Total Bsmt SF     0.629303
# 1st Flr SF        0.618486
# Bsmt Qual         0.612188
# Year Built        0.571849
# Garage Yr Blt     0.571849
# Garage Finish     0.557839
# Year Remod/Add    0.550370
# Fireplace Qu      0.538925
# Full Bath         0.537969
# TotRms AbvGrd     0.504014
# Mas Vnr Area      0.503579
# Fireplaces        0.471093
# Heating QC        0.458354
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize = (12,10))
train_df._get_numeric_data().corr()['SalePrice'].sort_values().plot(kind = 'barh')

# %%
plt.figure(figsize = (8,6))
train_df['SalePrice'].plot(kind='hist', bins = 50)

# %%
plt.figure(figsize = (8,6))
train_df['Overall Qual'].plot(kind='hist', bins = 10)

# %%
train_df.plot(y = 'SalePrice', x = 'Overall Qual', kind='scatter', figsize = (8,6))

# %%
sns.lmplot('Overall Qual', 'SalePrice', train_df, size = 7)

# %%
plt.figure(figsize = (8,6))
train_df['Gr Liv Area'].plot(kind = 'hist', bins = 30)

# %%
sns.lmplot('Gr Liv Area', 'SalePrice', train_df, size = 7)

# %%
predictors = train_df._get_numeric_data().corr()['SalePrice'].sort_values(ascending = False).keys()[1:9]
predictors
# Out:
# Index(['Overall Qual', 'Exter Qual', 'Gr Liv Area', 'Kitchen Qual',
#        'Garage Area', 'Garage Cars', 'Total Bsmt SF', '1st Flr SF'],
#       dtype='object')

# %%
data = train_df[['SalePrice','Overall Qual', 'Gr Liv Area', 'Garage Area', 'Garage Cars']]

y_vars = ['SalePrice']

x_vars = ['Overall Qual', 'Gr Liv Area', 'Garage Area', 'Garage Cars']

g = sns.pairplot(data = data,y_vars = y_vars, x_vars = x_vars,kind = 'reg')

g.fig.set_size_inches(15,5)

# %%
data = train_df[['SalePrice','Total Bsmt SF', '1st Flr SF', 'Garage Yr Blt', 'Year Built']]

y_vars = ['SalePrice']

x_vars = ['Total Bsmt SF', '1st Flr SF', 'Garage Yr Blt', 'Year Built']

g = sns.pairplot(data = data,y_vars = y_vars, x_vars = x_vars,kind = 'reg')

g.fig.set_size_inches(15,5)

# %%
predictors = ['Overall Qual', 'Gr Liv Area', 'Garage Area', 'Garage Cars',\
       'Total Bsmt SF', '1st Flr SF', 'Garage Yr Blt', 'Year Built']

X = train_df[predictors]
y = train_df['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state=8)

ss = StandardScaler()
ss.fit(X_train)
X_scaled = ss.transform(X_train)
X_test_scaled = ss.transform(X_test)

model = LinearRegression()

model.fit(X_scaled, y_train)

y_train_predict = model.predict(X_scaled)
y_test_predict = model.predict(X_test_scaled)

print(model.score(X_scaled, y_train),model.score(X_test_scaled, y_test))
# Out:
# 0.7936163597715324 0.7679336452030988

# %%
cross_val_score(model, X_scaled, y_train, cv = 5).mean()
# Out:
# 0.7644494680317286

# %%
def PlotY(y_test, y_test_predict):
    plt.figure(figsize = (10,8))
    plt.scatter(y_test, y_test_predict, c='steelblue', marker = 'o', edgecolor = 'white', label = 'Training data')
    plt.xlabel('Predicted Values (SalePrice)', fontsize = 15)
    plt.ylabel('Test Values (SalePrice)',fontsize = 15)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.show()
    
PlotY(y_test, y_test_predict)

# %%
def PlotResiduals(y_train_predict,y_train):
    plt.figure(figsize = (10,8))
    plt.scatter(y_train_predict, y_train - y_train_predict,
                c='steelblue', marker = 'o', s = 60.0, edgecolor = 'white', label = 'Training data', alpha =0.5)
    plt.scatter(y_test_predict, y_test - y_test_predict,
               c='limegreen', marker = 's', s = 60.0, edgecolor = 'white', label = 'Test Data', alpha = 0.5)
    plt.xlabel('True Values', fontsize = 15)
    plt.ylabel('Residuals', fontsize = 15)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.legend(loc = 'upper left', fontsize = 15)
    plt.hlines(y=0, xmin = -100000, xmax =600000, color = 'black', lw=2)
    plt.show()

# %%
PlotResiduals(y_train_predict,y_train)

# %%
pd.DataFrame({
    "X":predictors,
    "coefs": model.coef_
})
# Out:
#                X         coefs
# 0   Overall Qual  32382.229366
# 1    Gr Liv Area  21183.529009
# 2    Garage Area   6358.257735
# 3    Garage Cars   4874.470389
# 4  Total Bsmt SF   5886.008958
# 5     1st Flr SF   7124.211890
# 6  Garage Yr Blt   4506.841477
# 7     Year Built   4506.841477

# %%
def My_LMPlot(var, input_df):
    var = input_df[var]
    plt.figure(figsize=(10,8))
    plt.subplot(211)
    plt.xlim(var.min(), var.max()*1.1)

    ax = var.plot(kind='kde')

    plt.subplot(212)
    plt.xlim(var.min(), var.max()*1.1)
    sns.boxplot(x=var, orient = 'h')

# %%
My_LMPlot('SalePrice', train_df)

# %%
My_LMPlot('Overall Qual', train_df)

# %%
My_LMPlot('Gr Liv Area', train_df)

# %%
My_LMPlot('Garage Area', train_df)

# %%
My_LMPlot('Total Bsmt SF', train_df)

# %%
My_LMPlot('1st Flr SF', train_df)

# %%
# As it is now, we can see that many points for our strongest predicts lie outside of the whiskers of these box
# plots.  However, omitting them using the 1.5*IQR and 3.0*IQR rules lowers our predictive power when running
# models without the outliers. I manually removed only the moved extreme values from these variables, being 
# careful not to remove too much information from my strongest predictors!

#Note that I only did this for the continuous variables.

#Also note that we don't want to remove outliers based on SalePrice, that's our target!

new_outlier_train = train_df.loc[~(
    (train_df['Gr Liv Area'] > 5000) |
    (train_df['Garage Area'] > 1200) |
    (train_df['Total Bsmt SF'] > 3000) |
    (train_df['1st Flr SF'] > 3000)),:
]
print(train_df.shape)
print(new_outlier_train.shape)
# Out:
# (2051, 81)
# (2040, 81)

# %%
new_outlier_train.to_pickle('./assets/train_cleaned_edit.csv')

# %% [markdown]
# - Garage Year and Year Built were redundant, so we're leaving it out of the new LR model with outliers removed.

# %%
predictors = ['Overall Qual', 'Gr Liv Area', 'Garage Area', 'Garage Cars','Total Bsmt SF', '1st Flr SF', 'Year Built']

X = new_outlier_train[predictors]
y = new_outlier_train['SalePrice']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.25, random_state=8)

ss = StandardScaler()
ss.fit(X_train)
X_scaled = ss.transform(X_train)
X_test_scaled = ss.transform(X_test)

model = LinearRegression()

model.fit(X_scaled, y_train)

y_train_predict = model.predict(X_scaled)
y_test_predict = model.predict(X_test_scaled)

model.score(X_scaled, y_train),model.score(X_test_scaled, y_test)
# Out:
# (0.8229366046389619, 0.824035285029171)

# %%
cross_val_score(model, X_scaled,y_train).mean()
# Out:
# 0.8204274478940609

# %%
PlotResiduals(y_train_predict,y_train)

# %% [markdown]
# #### Cutting out some of these outliers boosted our train/test set accuracies from 79.4% / 76.8% to 82.3% / 82.4% using just the simple linear regression model with only 7 features.  We were also able to "tighten up" our residuals as seen from the PlotResiduals function.
#
# - In the next notebook, we're going to apply regularization methods to our linear regression models using comparing Ridge, Lasso, and ElasticNet.  This way, we can have the ML models help us figure out which other features are important, and how important they are compared to just what we've done here.
# - We'll also be able to make use of all of the other ordinal and nominal values we crafted previously.
